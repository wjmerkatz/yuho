# %%
import time
import numpy as np
import pandas as pd
import unicodedata


#from PIL import Image
from io import StringIO

# %matplotlib inline
import matplotlib.pyplot as plt

from IPython.core.display import display, HTML

# %%
import os

f = os.open('data/1301_20140624.html', 'r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-35fefece5cdb> in <module>()
#       1 import os
#       2
# ----> 3 f = os.open('data/1301_20140624.html', 'r')
#
# TypeError: an integer is required (got type str)

# %%
import codecs
import re

spltr = '大株主の状況'
f_in  = codecs.open('data/1301_20140624.html', 'r', 'utf-8')
ustr = f_in.read()
lustr = ustr.split(spltr)
df = pd.read_html('<table' + lustr[1].split('table')[1])[0]
df.columns = df.iloc[0]
df = df.iloc[1:, :]

# %%
spltr = '発行済株式'
f_in  = codecs.open('data/1301_20140624.html', 'r', 'utf-8')
ustr = f_in.read()
lustr = ustr.split(spltr)
df = pd.read_html('<table' + lustr[1].split('table')[1])[0]
df.columns = df.iloc[0]
df = df.iloc[1:, :]

# %%
import lxml.html

# %%
pd.

# %%
tkl = pd.read_html(ustr, header=0)

# %%
len(tkl)
# Out:
# 23

# %%
len(tkl)
# Out:
# 23

# %%
flist = ustr.split('<table')

# %%
len(flist)
# Out:
# 24

# %%
for x in tkl:
    display(x)
# Out:
#      種類  発行可能株式総数(株)
# 0  普通株式    437000000
# 1     計    437000000
#      種類  事業年度末現在発行数(株)(平成26年３月31日)  提出日現在発行数(株)(平成26年６月24日)  \
# 0  普通株式                  109282837                109282837
# 1     計                  109282837                109282837
#
#   上場金融商品取引所名又は登録認可金融商品取引業協会名  \
# 0             東京証券取引所(市場第一部)
# 1                          －
#
#                                                   内容
# 0  完全議決権株式であり、権利内容に何ら限定のない当社における標準となる株式。単元株式数は1,0...
# 1                                                  －
#                                 Unnamed: 0  \
# 0                               新株予約権の数(個)
# 1                        新株予約権のうち自己新株予約権の数
# 2                         新株予約権の目的となる株式の種類
# 3                       新株予約権の目的となる株式の数(株)
# 4                        新株予約権の行使時の払込金額(円)
# 5                               新株予約権の行使期間
# 6   新株予約権の行使により株式を発行する場合の株式の発行価格及び資本組入額(円)
# 7                              新株予約権の行使の条件
# 8                           新株予約権の譲渡に関する事項
# ...

# %%
import lxml.html

# %%
root = etree.fromstring(flist[1])
# Out:
# ' cellspacing="0" cellpadding="0" style="border-collapse:collapse;border:solid 0pt #000000;width:468.25pt;" class="align_center"><colgroup><col style="width:234.15pt;min-width:234.15pt;" /><col style="width:234.1pt;min-width:234.1pt;" /></colgroup><tbody><tr style="height:16.5pt"><td valign="middle" style="vertical-align:middle;border-top-style:solid;border-top-width:0.75pt;border-bottom-style:solid;border-bottom-width:0.75pt;border-left-style:solid;border-left-width:0.75pt;border-right-style:solid;border-right-width:0.75pt;"><p class="smt_tblC">種類</p></td><td valign="middle" style="vertical-align:middle;border-top-style:solid;border-top-width:0.75pt;border-bottom-style:solid;border-bottom-width:0.75pt;border-left-style:solid;border-left-width:0.75pt;border-right-style:solid;border-right-width:0.75pt;"><p class="smt_tblC">発行可能株式総数(株)</p></td></tr><tr style="height:16.5pt"><td valign="middle" style="vertical-align:middle;border-top-style:solid;border-top-width:0.75pt;border-bottom-sty
# ...

# %%
df
# Out:
# 0    種類 事業年度末現在発行数(株)(平成26年３月31日) 提出日現在発行数(株)(平成26年６月24日)  \
# 1  普通株式                 109282837               109282837
# 2     計                 109282837               109282837
#
# 0 上場金融商品取引所名又は登録認可金融商品取引業協会名  \
# 1             東京証券取引所(市場第一部)
# 2                          －
#
# 0                                                 内容
# 1  完全議決権株式であり、権利内容に何ら限定のない当社における標準となる株式。単元株式数は1,0...
# 2                                                  －

# %%
df
# Out:
# 0                                              氏名又は名称  \
# 1                                日本トラスティ・サービス信託銀行株式会社
# 2                                           株式会社りそな銀行
# 3                                      三井住友海上火災保険株式会社
# 4                                              農林中央金庫
# 5                                東洋製罐グループホールディングス株式会社
# 6                                      東京海上日動火災保険株式会社
# 7                               カッパ・クリエイトホールディングス株式会社
# 8                                               極洋秋津会
# 9   ザ チェース マンハッタン バンク エヌエイ ロンドン エス エル オムニバス アカウント(...
# 10                                           中央魚類株式会社
# 11                                                  計
#
# 0                                                  住所 所有株式数(千株)  \
# 1                                    東京都中央区晴海一丁目８番11号      6479
# 2                                 大阪府大阪市中央区備後町二丁目２番１号      5234
# 3                                  東京都千代田区神田駿河台三丁目９番地      4501
# ...

# %%
ntag = '発行済株式'

# %%
print(lustr[1])
# Out:
# 】</h4><p class="smt_unitR" style="text-align:right;padding-left:359.2pt;">　　(平成26年３月31日現在)</p><div class="tbld" style="text-align:center;margin-left:0.25pt;margin-right:0pt;margin-top:0pt;margin-bottom:0pt;"><table cellspacing="0" cellpadding="0" style="border-collapse:collapse;border:solid 0pt #000000;width:476.3pt;" class="align_center"><colgroup><col style="width:147.0pt;min-width:147.0pt;" /><col style="width:173.3pt;min-width:173.3pt;" /><col style="width:51.0pt;min-width:51.0pt;" /><col style="width:105.0pt;min-width:105.0pt;" /></colgroup><tbody><tr style="height:22.5pt"><td valign="middle" style="vertical-align:middle;border-top-style:solid;border-top-width:0.75pt;border-bottom-style:solid;border-bottom-width:0.75pt;border-left-style:solid;border-left-width:0.75pt;border-right-style:solid;border-right-width:0.75pt;"><p class="smt_tblC">氏名又は名称</p></td><td valign="middle" style="vertical-align:middle;border-top-style:solid;border-top-width:0.75pt;border-bottom-style:solid;borde
# ...

# %%
print(ustr)
# Out:
# <!--?xml version="1.0" encoding="utf-8" ?--><html xmlns="http://www.w3.org/1999/xhtml" xmlns:xbrldi="http://xbrl.org/2006/xbrldi" xmlns:xbrli="http://www.xbrl.org/2003/instance" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:link="http://www.xbrl.org/2003/linkbase" xmlns:jpcrp_cor="http://disclosure.edinet-fsa.go.jp/taxonomy/jpcrp/2013-08-31/jpcrp_cor" xmlns:iso4217="http://www.xbrl.org/2003/iso4217" xmlns:jppfs_cor="http://disclosure.edinet-fsa.go.jp/taxonomy/jppfs/2013-08-31/jppfs_cor" xmlns:jpcrp030000-asr_e00012-000="http://disclosure.edinet-fsa.go.jp/jpcrp030000/asr/001/E00012-000/2014-03-31/01/2014-06-24" xmlns:jpdei_cor="http://disclosure.edinet-fsa.go.jp/taxonomy/jpdei/2013-08-31/jpdei_cor" xmlns:ix="http://www.xbrl.org/2008/inlineXBRL" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:ixt="http://www.xbrl.org/inlineXBRL/transformation/2011-07-31"><head><title>0104010_honbun_0164100102604.htm</title><meta http-equiv="X-UA-Compatible" content="IE=EmulateIE7" /><met
# ...

# %%
dir(f_in)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'encoding',
#  'errors',
#  'read',
#  'reader',
#  'readline',
#  'readlines',
#  'reset',
#  'seek',
#  'stream',
#  'write',
#  'writelines',
#  'writer']

# %%
dir(f_in)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'encoding',
#  'errors',
#  'read',
#  'reader',
#  'readline',
#  'readlines',
#  'reset',
#  'seek',
#  'stream',
#  'write',
#  'writelines',
#  'writer']

# %%
# %ls data
# Out:
# 1301_20140624.html  3896_20170628.html  6407_20160623.html  8070_20160331.html
# 1301_20150624.html  3896_20180628.html  6407_20170623.html  8070_20160622.html
# 1301_20160624.html  3901_20150327.html  6407_20180622.html  8070_20160628.html
# 1301_20170627.html  3901_20160330.html  6409_20140625.html  8070_20160629.html
# 1301_20180626.html  3901_20170329.html  6409_20150624.html  8070_20170329.html
# 1332_20140626.html  3901_20180329.html  6409_20160622.html  8070_20170621.html
# 1332_20150625.html  3902_20150327.html  6409_20170622.html  8070_20170629.html
# 1332_20160628.html  3902_20160329.html  6409_20180622.html  8070_20180329.html
# 1332_20170628.html  3902_20170328.html  6412_20140627.html  8070_20180529.html
# 1332_20180627.html  3902_20180327.html  6412_20150626.html  8070_20180621.html
# 1333_20140626.html  3903_20150730.html  6412_20160629.html  8070_20180628.html
# 1333_20150625.html  3903_20160728.html  6412_20170629.html  8070_20180629.html
# ...
